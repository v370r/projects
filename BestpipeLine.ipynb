# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importing

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
X_full = pd.read_csv("/content/drive/MyDrive/kaggle/home-data-for-ml-course/train.csv",index_col='Id')
X_test_full = pd.read_csv("/content/drive/MyDrive/kaggle/home-data-for-ml-course/test.csv",index_col='Id')
y = X_full.SalePrice
X_full.drop(["SalePrice"],axis=1,inplace = True)
X_train_full,X_valid_full,y_train,y_valid = train_test_split(X_full,y,train_size=0.8,random_state = 1)

# %%
X_train_full.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# Id                                      ...
# 922           90       RL         67.0  ...    2008       WD        Normal
# 521          190       RL         60.0  ...    2008       WD        Normal
# 402           20       RL         65.0  ...    2006      New       Partial
# 281           60       RL         82.0  ...    2007       WD        Normal
# 1402          60       RL         62.0  ...    2008       WD        Normal
#
# [5 rows x 79 columns]

# %%
? pd.unique()

# %%
# "Cardinality" means the number of unique values in a column
# Select categorical columns with relatively low cardinality (convenient but arbitrary)
categorical_cols = [cname for cname in X_train_full.columns if
                    X_train_full[cname].nunique() < 10 and  #nuniques means no of uniques
                    X_train_full[cname].dtype == "object"]

# Select numerical columns
numerical_cols = [cname for cname in X_train_full.columns if 
                X_train_full[cname].dtype in ['int64', 'float64']]

# Keep selected columns only
my_cols = categorical_cols + numerical_cols
X_train = X_train_full[my_cols].copy()
X_valid = X_valid_full[my_cols].copy()
X_test = X_test_full[my_cols].copy()
Y_test = X_test.SalePrice
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-a96f2501f25e> in <module>()
#      14 X_valid = X_valid_full[my_cols].copy()
#      15 X_test = X_test_full[my_cols].copy()
# ---> 16 Y_test = X_test.SalePrice
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'SalePrice'

# %%
  X_train.head()

# %% [markdown]
# ## Import

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
# %%time
# ["mean","median","most_frequent",'constant']
numerical_transformer = SimpleImputer(strategy='constant')
categorical_transformer = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy = 'constant')),
    ('onehot',OneHotEncoder(handle_unknown='ignore'))
]) 
# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

model = RandomForestRegressor(n_estimators=100,random_state=1) # Your code here
my_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                              ('model', model)
                             ])

# Preprocessing of training data, fit model 
my_pipeline.fit(X_train, y_train)

# Preprocessing of validation data, get predictions
preds = my_pipeline.predict(X_valid)

# Evaluate the model
score = mean_absolute_error(y_valid, preds)
print('MAE:', score).
# Out:
# MAE: 16312.284109589044
# CPU times: user 2.72 s, sys: 2.8 ms, total: 2.72 s
# Wall time: 2.72 s

# %%
preds_test = my_pipeline.predict(X_test)

# %%
X_test["SalePredict"] = preds_test

# %%
X_test.head()
# Out:
#      MSZoning Street Alley LotShape  ... MiscVal MoSold YrSold SalePredict
# Id                                   ...
# 1461       RH   Pave   NaN      Reg  ...       0      6   2010   129019.66
# 1462       RL   Pave   NaN      IR1  ...   12500      6   2010   153444.00
# 1463       RL   Pave   NaN      IR1  ...       0      3   2010   179745.59
# 1464       RL   Pave   NaN      IR1  ...       0      6   2010   183649.00
# 1465       RL   Pave   NaN      IR1  ...       0      1   2010   196784.22
#
# [5 rows x 77 columns]

# %%
output = pd.DataFrame({"Id":X_test.index,"SalePrice":preds_test})

# %%
output.to_csv("/content/drive/MyDrive/kaggle/home-data-for-ml-course/submission.csv",index=False)
