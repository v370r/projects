# %% [markdown]
# <a href="https://colab.research.google.com/github/v370r/projects/blob/master/covid19_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Covid19 Data Analysis
# ------------------------------------------

# %% [markdown]
# ### Let's Import the modules

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### Task 2.1: importing covid19 dataset
# importing "Covid19_Confirmed_dataset.csv" from "./Dataset" folder.

# %%
df = pd.read_csv("Datasets/covid19_Confirmed_dataset.csv")
df.tail(8)
# Out:
#                   Province/State         Country/Region  ...  4/29/20  4/30/20
# 258  Falkland Islands (Malvinas)         United Kingdom  ...       13       13
# 259    Saint Pierre and Miquelon                 France  ...        1        1
# 260                          NaN            South Sudan  ...       34       35
# 261                          NaN         Western Sahara  ...        6        6
# 262                          NaN  Sao Tome and Principe  ...        8       14
# 263                          NaN                  Yemen  ...        6        6
# 264                          NaN                Comoros  ...        0        1
# 265                          NaN             Tajikistan  ...        0       15
#
# [8 rows x 104 columns]

# %% [markdown]
# #### Let's check the shape of the dataframe

# %%
df.shape
# Out:
# (266, 104)

# %% [markdown]
# ### Task 2.2: Delete the useless columns

# %%
df.drop(["Lat","Long"],axis= 1,inplace=True)
df.head()
# Out:
#   Province/State Country/Region  1/22/20  ...  4/28/20  4/29/20  4/30/20
# 0            NaN    Afghanistan        0  ...     1828     1939     2171
# 1            NaN        Albania        0  ...      750      766      773
# 2            NaN        Algeria        0  ...     3649     3848     4006
# 3            NaN        Andorra        0  ...      743      743      745
# 4            NaN         Angola        0  ...       27       27       27
#
# [5 rows x 102 columns]

# %% [markdown]
# ### Task 2.3: Aggregating the rows by the country

# %%
df = df.groupby("Country/Region").sum()
df.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  4/28/20  4/29/20  4/30/20
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1828     1939     2171
# Albania               0        0        0  ...      750      766      773
# Algeria               0        0        0  ...     3649     3848     4006
# Andorra               0        0        0  ...      743      743      745
# Angola                0        0        0  ...       27       27       27
#
# [5 rows x 100 columns]

# %%
df.shape
# Out:
# (187, 100)

# %% [markdown]
# ### Task 2.4: Visualizing data related to a country for example China
# visualization always helps for better understanding of our data.

# %%
df.loc["China"].plot()
df.loc["India"].plot()
plt.legend()
plt.show()

# %% [markdown]
# ### Task3: Calculating a good measure
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
df.loc['China'].plot()

# %%
df.loc["China"][:3].plot()

# %% [markdown]
# ### task 3.1: caculating the first derivative of the curve

# %%
df.loc["China"][:].diff().plot()

# %% [markdown]
# ### task 3.2: find maxmimum infection rate for China

# %%
df.loc["China"].diff().max()
# Out:
# 15136.0

# %%
df.loc["India"].diff().max()
# Out:
# 1893.0

# %% [markdown]
# ### Task 3.3: find maximum infection rate for all of the countries.

# %%
countries = list(df.index)
max_infectionsrates_list = []
for country in countries:
    max_infectionsrates_list.append(df.loc[country].diff().max())
max_infectionsrates_list
# Out:
# [232.0,
#  34.0,
#  199.0,
#  43.0,
#  5.0,
#  6.0,
#  291.0,
#  134.0,
#  497.0,
#  1321.0,
#  105.0,
#  7.0,
#  301.0,
#  641.0,
#  12.0,
#  1485.0,
#  2454.0,
#  4.0,
#  19.0,
#  1.0,
#  104.0,
#  92.0,
#  7.0,
#  7502.0,
#  26.0,
#  137.0,
#  41.0,
#  21.0,
#  6.0,
#  45.0,
#  31.0,
#  203.0,
#  2778.0,
#  31.0,
#  21.0,
#  1138.0,
#  15136.0,
#  353.0,
#  1.0,
#  57.0,
#  81.0,
#  37.0,
#  113.0,
#  96.0,
#  63.0,
#  58.0,
#  381.0,
#  391.0,
#  99.0,
#  156.0,
#  5.0,
#  371.0,
#  11536.0,
#  269.0,
#  32.0,
#  130.0,
#  7.0,
#  134.0,
#  20.0,
#  9.0,
#  5.0,
#  267.0,
#  26849.0,
#  38.0,
#  5.0,
#  42.0,
#  6933.0,
#  403.0,
#  156.0,
#  6.0,
#  68.0,
#  167.0,
#  132.0,
#  12.0,
#  10.0,
#  3.0,
#  72.0,
#  210.0,
#  99.0,
#  1893.0,
#  436.0,
#  3186.0,
#  91.0,
#  1515.0,
#  1131.0,
#  6557.0,
#  52.0,
#  1161.0,
#  40.0,
#  264.0,
#  29.0,
#  851.0,
#  289.0,
#  300.0,
#  69.0,
#  3.0,
#  48.0,
#  61.0,
#  17.0,
#  13.0,
#  21.0,
#  90.0,
#  234.0,
#  7.0,
#  14.0,
# ...

# %%
df["max_infections_rates"] =max_infectionsrates_list
df.head()
# Out:
#                 1/22/20  1/23/20  ...  4/30/20  max_infections_rates
# Country/Region                    ...
# Afghanistan           0        0  ...     2171                 232.0
# Albania               0        0  ...      773                  34.0
# Algeria               0        0  ...     4006                 199.0
# Andorra               0        0  ...      745                  43.0
# Angola                0        0  ...       27                   5.0
#
# [5 rows x 101 columns]

# %%
print(df.loc["India"])
# Out:
# 1/22/20                     0.0
# 1/23/20                     0.0
# 1/24/20                     0.0
# 1/25/20                     0.0
# 1/26/20                     0.0
#                          ...
# 4/27/20                 29451.0
# 4/28/20                 31324.0
# 4/29/20                 33062.0
# 4/30/20                 34863.0
# max_infections_rates     1893.0
# Name: India, Length: 101, dtype: float64

# %% [markdown]
# ### Task 3.4: create a new dataframe with only needed column

# %%
corona_data = pd.DataFrame(df["max_infections_rates"])
corona_data
# Out:
#                     max_infections_rates
# Country/Region
# Afghanistan                        232.0
# Albania                             34.0
# Algeria                            199.0
# Andorra                             43.0
# Angola                               5.0
# ...                                  ...
# West Bank and Gaza                  66.0
# Western Sahara                       4.0
# Yemen                                5.0
# Zambia                               9.0
# Zimbabwe                             8.0
#
# [187 rows x 1 columns]

# %% [markdown]
# ### Task4:
# - Importing the WorldHappinessReport.csv dataset
# - selecting needed columns for our analysis
# - join the datasets
# - calculate the correlations as the result of our analysis

# %% [markdown]
# ### Task 4.1 : importing the dataset

# %%
happiness_report = pd.read_csv("Datasets/worldwide_happiness_report.csv")
hr = happiness_report
hr.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %% [markdown]
# ### Task 4.2: let's drop the useless columns

# %%
useless_col = ["Overall rank","Score","Generosity","Perceptions of corruption",]
hr.drop(useless_col,axis =1 ,inplace =True)
hr.head()
# Out:
#   Country or region  ...  Freedom to make life choices
# 0           Finland  ...                         0.596
# 1           Denmark  ...                         0.592
# 2            Norway  ...                         0.603
# 3           Iceland  ...                         0.591
# 4       Netherlands  ...                         0.557
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Task 4.3: changing the indices of the dataframe

# %%
hr.set_index("Country or region",inplace =True)
hr
# Out:
#                           GDP per capita  ...  Freedom to make life choices
# Country or region                         ...
# Finland                            1.340  ...                         0.596
# Denmark                            1.383  ...                         0.592
# Norway                             1.488  ...                         0.603
# Iceland                            1.380  ...                         0.591
# Netherlands                        1.396  ...                         0.557
# ...                                  ...  ...                           ...
# Rwanda                             0.359  ...                         0.555
# Tanzania                           0.476  ...                         0.417
# Afghanistan                        0.350  ...                         0.000
# Central African Republic           0.026  ...                         0.225
# South Sudan                        0.306  ...                         0.010
#
# ...

# %%
hr.shape
# Out:
# (156, 4)

# %%
data = corona_data.join(hr,how = "inner")
data.head()
# Out:
#              max_infections_rates  ...  Freedom to make life choices
# Afghanistan                 232.0  ...                         0.000
# Albania                      34.0  ...                         0.383
# Algeria                     199.0  ...                         0.086
# Argentina                   291.0  ...                         0.471
# Armenia                     134.0  ...                         0.283
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Task4.4: now let's join two dataset we have prepared

# %% [markdown]
# #### Corona Dataset :

# %%
corona_data.head()
# Out:
#                 max_infections_rates
# Country/Region
# Afghanistan                    232.0
# Albania                         34.0
# Algeria                        199.0
# Andorra                         43.0
# Angola                           5.0

# %%
corona_data.shape
# Out:
# (187, 1)

# %%
corona_data.shape
# Out:
# (187, 1)

# %% [markdown]
# #### wolrd happiness report Dataset :

# %%
hr.shape
# Out:
# (156, 4)

# %%
data = corona_data.join(hr,how = "inner")
data
# Out:
#              max_infections_rates  ...  Freedom to make life choices
# Afghanistan                 232.0  ...                         0.000
# Albania                      34.0  ...                         0.383
# Algeria                     199.0  ...                         0.086
# Argentina                   291.0  ...                         0.471
# Armenia                     134.0  ...                         0.283
# ...                           ...  ...                           ...
# Venezuela                    29.0  ...                         0.154
# Vietnam                      19.0  ...                         0.543
# Yemen                         5.0  ...                         0.143
# Zambia                        9.0  ...                         0.431
# Zimbabwe                      8.0  ...                         0.361
#
# [143 rows x 5 columns]

# %% [markdown]
# ### Task 4.5: correlation matrix

# %%
data.corr()
# Out:
#                               max_infections_rates  ...  Freedom to make life choices
# max_infections_rates                      1.000000  ...                      0.078196
# GDP per capita                            0.250118  ...                      0.394603
# Social support                            0.191958  ...                      0.456246
# Healthy life expectancy                   0.289263  ...                      0.427892
# Freedom to make life choices              0.078196  ...                      1.000000
#
# [5 rows x 5 columns]

# %%
sns.heatmap(data.corr(),annot= True)

# %% [markdown]
# ### Task 5: Visualization of the results
# our Analysis is not finished unless we visualize the results in terms figures and graphs so that everyone can understand what you get out of our analysis

# %%
data.head()
# Out:
#              max_infections_rates  ...  Freedom to make life choices
# Afghanistan                 232.0  ...                         0.000
# Albania                      34.0  ...                         0.383
# Algeria                     199.0  ...                         0.086
# Argentina                   291.0  ...                         0.471
# Armenia                     134.0  ...                         0.283
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Task 5.1: Plotting GDP vs maximum Infection rate

# %%
x = data["GDP per capita"]
y = data["max_infections_rates"]
sns.scatterplot(x,y)

# %%
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ### Task 5.2: Plotting Social support vs maximum Infection rate

# %%
sns.regplot(data["Social support"],np.log(data["max_infections_rates"])) # np.log is natural logarithm = 1n

# %% [markdown]
# ### Task 5.3: Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = data["Healthy life expectancy"]
y = data["max_infections_rates"]
sns.scatterplot(x,y)

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ### Task 5.4: Plotting Freedom to make life choices vs maximum Infection rate

# %%
x = data["Freedom to make life choices"]
y = data["max_infections_rates"]
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))
